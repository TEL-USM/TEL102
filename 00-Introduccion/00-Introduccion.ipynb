# %% [markdown]
# <img src="images/elo-tel.png" alt="" width="130px" align="left"/>
# <img src="images/utfsm.png" alt="" width="150px" align="right"/>
# <br/>
# <div align="center">
# <h2>TEL-102 Seminario de Programación</h2><br/>
# <h1>Presentación e Introducción al Curso</h1>
# <br/><br/>
# Patricio Olivares<br/><br/>
# Ingeniería Civil Telemática<br/>
# Departamento de Electrónica<br/>
# Universidad Técnica Federico Santa María
# </div>

# %% [markdown]
# # Resultados de Aprendizaje

# %% [markdown]
# - **Implementa** soluciones algorítmicas, aplicando diferentes metodologías de programación y conceptos matemáticos abstractos, para resolver problemas de diversa índole.
# - **Utiliza** métodos, técnica y teoría, de acuerdo con los fundamentos Ciencias Básicas y/o Ciencias de la Ingeniería para la resolución de problemas.
# - **Identifica** estrategias de registro de información técnica, utilizando fuentes relevantes y confiables para responder a las necesidades propias de sus actividades y contextos disciplinares en los cuales se desenvuelve.

# %% [markdown]
# # Contenidos

# %% [markdown]
# 1. **Unidad 1: Introducción a Sistema Operativo Linux**
# 2. **Unidad 2: Programación básica en C**
#    - Compilación
#    - Tipos de datos
#    - Estructuras de control
# 3. **Unidad 3: Introducción a las metodologías de desarrollo**
#    - Desarrollo ágil: *eXtreme Programming*
#    - Estándares de Programación GNU
# 4. **Unidad 4: Manejo de Memoria**
#    - Estructura general de programa en memoria
#    - Administración de Memoria
# 5. **Unidad 5: Estructuras de datos básicas en C y Depuración**
# 6. **Unidad 6: Orientación a Objetos**
#    - Encapsulación, Clases y Objetos
#    - Herencia básica
# 7. **Interfaces Gráficas y Objetos**
#    - Widgets
#    - Gráficos
#
# **Enfoque Práctico**

# %% [markdown]
# # Estructura del curso

# %% [markdown]
# ## Horarios
# * Par 201: Lunes 5-6 (11:05 a 12:15) y Martes 5-6 (11:05 a 12:15) - Prof: Patricio Olivares R.

# %% [markdown]
# # Evaluación del Curso

# %% [markdown]
# ## Individual (50%)
#
# * 4 Controles + 1 Control Recuperativo (CR, abierto)
# * El CR reemplaza la peor nota entre los 4 Controles.

# %% [markdown]
# ## Grupal (50%)
# * Proyecto: 3-4 integrantes
# * Entrega de 3 hitos (80%)
# * Evaluación profesor (20%)

# %% [markdown]
# ## Prácticos
#
# Durante el semestre, se ofrecerán **prácticos**: actividades opcionales que permiten reforzar los contenidos vistos en clases y preparar mejor los controles.
#
# - Habrá **un práctico asociado a cada uno de los 4 controles** del curso.
# - Cada práctico ayuda a profundizar los contenidos previos a un control.
# - Los prácticos entregan **puntos adicionales** que se suman al puntaje del control correspondiente.
# - Puedes obtener hasta **10 puntos extra por cada control**, dependiendo del desempeño en su práctico asociado.
# - Estos puntos se suman directamente al control, sin que el puntaje total supere el máximo (es decir, 100 puntos).
#
# **Participar en los prácticos es altamente recomendable** para quienes quieran consolidar su aprendizaje y mejorar su rendimiento en los controles.

# %% [markdown]
# ## Ponderación
#
# ### Definiciones
#
# - **PC**: Promedio de Controles
# - **PP**: Promedio del Proyecto
# - **EP**: Evaluación del Profesor
# - **NP**: Nota del Proyecto
# - **NF**: Nota Final del curso
#
# ### Fórmulas
#
# - $NP = 0.8 \times PP + 0.2 \times EP$
# - $NF = 0.5 \times PC + 0.5 \times NP$
#
# ### Condiciones para aprobar
#
# - $PC \geq 50$
# - $NP \geq 50$
#
#
# 1. Si ambas condiciones PC $\geq$ 50 y NP $\geq$ 50 se cumplen (también aplica si ambas condiciones **no se cumplen simultáneamente** ):
#     * **NF = 0.5 $\times$ PC + 0.5 $\times$ NP.**
# 2. Si PC < 50:
#     * **NF = 0.95 $\times$ PC + 0.05 $\times$ NP.**
# 3. Si NP < 50:
#     * **NF = 0.05 $\times$ PC + 0.95 $\times$ NP.**

# %% [markdown]
# Adicionalmente existirán actividades prácticas opcionales (una por cada control, excepto para el control recuperativo), las cuales podrán contribuir con un máximo de 10 puntos al control respectivo (nota satura en 100).

# %% [markdown]
# # Proyecto

# %% [markdown]
# * Proyecto orientado a la realización de un taller para alumnos de enseñanza media sobre problemas matemáticos o físicos
# * 3 a 4 integrantes
# * Equipos de estudiantes con conocimientos similares
# * Hitos:
#     * **Hito 0**: Selección e inscripción de grupo y tema de proyecto
#     * **Hito 1**: Problema matemático a Algoritmo
#     * **Hito 2**: Visualización gráfica de resultados
#     * **Hito 3**: Parametrización utilizando interfaces
#     <!-- yo tenia considerado presentaciones en clases + un hito 0 de la idea -->

# %% [markdown]
# ## Calendario de Evaluaciones.
#
# Disponible en AULA USM. Note que:
# * Los prácticos se realizarán los días Lunes en horario regular de clases.
# * Los controles ocurrirán los días Martes.
# * Los hitos del proyecto se entregarán en días Viernes a más tardar a las 23:59:59, horario de Chile Continental.
#
# El calendarío puede sufrir modificaciónes, las cuales se informarán con debida antelación.

# %% [markdown]
# # Reglas de clases y evaluaciones
# * Las clases y evaluaciones serán realizadas **presencialmente** en las fechas y horarios indicados salvo aquellas que se indique explícitamente.
# * Los alumnos deben respetar íntegramente el Código de Honor del curso.

# %% [markdown]
# # Código de honor
# Al realizar una evaluación en este curso, cada estudiante adhiere a las siguientes reglas:
# * Desarrollar evaluación que así se indique deberá se realizada por su propia cuenta, sin ayuda de terceros.
# * No participar en actividad alguna que pretenda mejorar deshonestamente su resultado, o para mejorar o perjudicar los resultados de otros.
# * No publicar sus respuestas durante el desarrollo de dicha evaluación por ningún medio público.
# * Subir sus respuestas a la plataforma AULA USM con su propio login institucional.
# * No permitir que nadie más use su nombre de usuario y/o contraseña institucional.

# %% [markdown]
# En caso de constatar que algún estudiante ha cometido una infracción a alguna de estas reglas y dependiendo la gravedad de la falta, la Coordinación del curso tomará medidas que van desde evaluación con nota 0, hasta la reprobación inmediata del curso, con envı́o de antecedentes a Comisión Universitaria. La Comisión Universitaria en estos casos toma medidas que van desde la amonestación hasta la expulsión del estudiante de la Universidad.
# Para la evaluación objetiva de potenciales infracciones a este código, se utilizará software especializado en la detección de plagio.

# %% [markdown]
# # Material de la asignatura
# * Se habilitará el contenido en la página de **AULA USM**, el medio oficial del curso: https://aula.usm.cl
# * Allí podrán encontrar todo lo necesario para cursar exitosamente la asignatura.
# * Además, contaremos con un servidor en [Discord](https://discord.gg/dYHxR3qHM3).
#
# Consultas a:
# * Prof. Patricio Olivares R.: [patricio.olivaresr@usm.cl](mailto:patricio.olivaresr@usm.cl)
