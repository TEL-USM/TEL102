# %% [markdown]
# <img src="images/elo-tel.png" alt="" width="130px" align="left"/>
# <img src="images/utfsm.png" alt="" width="150px" align="right"/>
# <br/>
# <div align="center">
# <h2>TEL-102 Seminario de Programación</h2><br/>
# <h1>Introducción a Linux/Bash</h1>
# <br/><br/>
# Dr. Nicolás Gálvez Ramírez<br/>
# Ingeniería Civil Telemática<br/>
# Departamento de Eléctronica<br/>
# Universidad Técnica Federico Santa María
# </div>

# %% [markdown]
# # Introducción a Linux

# %% [markdown]
# * Linux es un sistema operativo con grandes ventajas
#     * Seguridad
#     * Control y acceso abierto
#     * Bajo costo
#     * Buen rendimiento
#     * Compatibilidad con la red

# %% [markdown]
# * La consola linux permite acceder a un conjunto de herramientas de línea de comando que puede acelerar considerablemente la interacción con el sistema.

# %% [markdown]
# # Comandos básicos

# %% [markdown]
# * **ls**: Lista los archivos de un directorio actual

# %%
ls
# Out:
# 01_Introduccion_a_Linux.html    01_Introduccion_a_Linux.slides.html  archivos/
# 01_Introduccion_a_Linux.ipynb*  01_Introduccion_a_Linux.slides.pdf   images/

# %%
ls archivos/
# Out:
# archivo1.txt  archivo2.txt  hola  hola.cpp

# %% [markdown]
# # Comandos básicos

# %% [markdown]
# * **pwd**: Muestra directorio actual

# %%
pwd
# Out:
# '/home/nikofunk/Documentos/Progra/TEL-102/2022/repo/js-2022/01_Introduccion_a_Linux'

# %% [markdown]
# * **cd**: Accede a un  directorio

# %%
cd archivos/
# Out:
# /home/nikofunk/Documentos/Progra/TEL-102/2022/repo/js-2022/01_Introduccion_a_Linux/archivos

# %%
ls
# Out:
# archivo1.txt  archivo2.txt  hola  hola.cpp

# %% [markdown]
# # Comandos básicos

# %% [markdown]
# * **mkdir**: Crea directorio

# %%
mkdir nuevos_archivos

# %%
ls
# Out:
# archivo1.txt  archivo2.txt  hola  hola.cpp  nuevos_archivos/

# %% [markdown]
# * **rmdir**: Elimina directorio (debe estar vacío)

# %%
rmdir nuevos_archivos

# %%
ls
# Out:
# archivo1.txt  archivo2.txt  hola  hola.cpp

# %% [markdown]
# # Comandos básicos

# %% [markdown]
# * **cp**: Copia archivos

# %%
cp archivo1.txt nuevo_archivo.txt

# %%
ls
# Out:
# archivo1.txt  archivo2.txt  hola  hola.cpp  nuevo_archivo.txt

# %% [markdown]
# * **rm**: Elimina archivos

# %%
rm nuevo_archivo.txt

# %%
ls
# Out:
# archivo1.txt  archivo2.txt  hola  hola.cpp

# %% [markdown]
# # Comandos básicos

# %% [markdown]
# * **mv**: Mueve o renombra archivos o directorios

# %%
mv archivo1.txt archivo_renombrado.txt

# %%
ls
# Out:
# archivo2.txt  archivo_renombrado.txt  hola  hola.cpp

# %%
mv archivo_renombrado.txt archivo1.txt

# %% [markdown]
# # Comandos básicos

# %% [markdown]
# * **chmod**: Comando para cambiar permisos de utilización de un archivo o carpeta

# %%
ls -la
# Out:
# total 44
# drwxr-xr-x 2 nikofunk nikofunk  4096 ago 15 22:16 ./
# drwxr-xr-x 5 nikofunk nikofunk  4096 ago 15 22:14 ../
# -rw-r--r-- 1 nikofunk nikofunk     2 ago 15 18:17 archivo1.txt
# -rw-r--r-- 1 nikofunk nikofunk     2 ago 15 18:17 archivo2.txt
# -rw-r--r-- 1 nikofunk nikofunk 21120 ago 15 22:05 hola
# -rw-r--r-- 1 nikofunk nikofunk   106 ago 15 18:17 hola.cpp

# %%
# %%bash
# chmod +x hola

# %%
ls -la
# Out:
# total 44
# drwxr-xr-x 2 nikofunk nikofunk  4096 ago 15 22:16 ./
# drwxr-xr-x 5 nikofunk nikofunk  4096 ago 15 22:14 ../
# -rw-r--r-- 1 nikofunk nikofunk     2 ago 15 18:17 archivo1.txt
# -rw-r--r-- 1 nikofunk nikofunk     2 ago 15 18:17 archivo2.txt
# -rwxr-xr-x 1 nikofunk nikofunk 21120 ago 15 22:05 hola*
# -rw-r--r-- 1 nikofunk nikofunk   106 ago 15 18:17 hola.cpp

# %% [markdown]
# # Comandos básicos

# %% [markdown]
# * Ejecución de programas ejecutables

# %%
# %%bash
# ./hola
# Out:
# hola mundo

# %% [markdown]
# # Referencias

# %% [markdown]
# Curso básico Linux: http://www.ee.surrey.ac.uk/Teaching/Unix/
